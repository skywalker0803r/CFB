# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/CFB/blob/main/%E6%BB%BE%E5%8B%95%E5%BC%8F%E9%A0%90%E6%B8%ACy2_300%E9%96%93%E9%9A%94_95%25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib
import numpy as np

# 改style要在改font之前
# plt.style.use('seaborn')

matplotlib.font_manager.fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
matplotlib.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2025-06-28 01:57:21--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 172.217.12.14, 2607:f8b0:4025:810::200e
# Connecting to drive.google.com (drive.google.com)|172.217.12.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2025-06-28 01:57:21--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.12.1, 2607:f8b0:4025:810::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.12.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# TaipeiSansTCBeta-Re 100%[===================>]  19.70M  52.2MB/s    in 0.4s
#
# 2025-06-28 01:57:27 (52.2 MB/s) - ‘TaipeiSansTCBeta-Regular.ttf’ saved [20659344/20659344]

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/脫硫劑優化改善/20240916-CFB2脫硫劑優化改善.xlsx')
col = df.columns
df = df.iloc[1:,:]
df.columns = col
df = df.set_index('Unnamed: 0')
df.index.name = 'datetime'
df
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
#                     MLUT4_AIA792101A MLUT4_AIA792101B MLUT4_AIC-232B  \
# datetime
# 2024-01-01 00:00:00         5.540932              6.8      67.034424
# 2024-01-01 00:05:00         5.533478              6.8      66.662524
# 2024-01-01 00:10:00         5.526025              6.8      64.320729
# 2024-01-01 00:15:00         5.518571         6.801543      64.840762
# 2024-01-01 00:20:00         5.511117         6.819977      64.390831
# ...                              ...              ...            ...
# 2024-09-15 23:35:00         6.258452         5.140339     114.166438
# 2024-09-15 23:40:00         6.284992         5.166336     106.669841
# 2024-09-15 23:45:00         6.232171         5.225976     104.663595
# 2024-09-15 23:50:00          6.20333          5.14117     103.246788
# 2024-09-15 23:55:00         6.007071         4.972081     110.111657
#
#                     MLUT4_AT-232A MLUT4_AT-237 MLUT4_AT-240 MLUT4_AT-240A  \
# datetime
# 2024-01-01 00:00:00    151.208024     9.623605     8.619934      8.619934
# 2024-01-01 00:05:00    150.811453     9.616252     8.147002      8.147002
# 2024-01-01 00:10:00    151.708113     9.608899     8.247992      8.247992
# 2024-01-01 00:15:00    151.283528     9.600898      7.60582       7.60582
# 2024-01-01 00:20:00    150.994896     9.581994     6.110485      6.110485
# ...                           ...          ...          ...           ...
# 2024-09-15 23:35:00    209.520746     9.360355    13.105704     13.105704
# 2024-09-15 23:40:00    208.177318     9.280099     9.903673      9.903673
# 2024-09-15 23:45:00    211.564232     9.359701     9.345572      9.345572
# 2024-09-15 23:50:00    206.570014     9.211132     8.303164      8.303164
# 2024-09-15 23:55:00    209.432213     9.231066     8.933592      8.933592
#
#                     MLUT4_FIC-231A MLUT4_FIC-231B MLUT4_FIC-231C  ...  \
# datetime                                                          ...
# 2024-01-01 00:00:00      20.605973              0      17.456094  ...
# 2024-01-01 00:05:00       20.18102              0      17.449118  ...
# 2024-01-01 00:10:00      20.200619              0      17.442142  ...
# 2024-01-01 00:15:00      20.220218              0      17.571883  ...
# 2024-01-01 00:20:00      20.549012              0      17.339679  ...
# ...                            ...            ...            ...  ...
# 2024-09-15 23:35:00      12.795748      11.854892        12.8422  ...
# 2024-01-01 00:15:00     874.888616     59.200001     15.000000   0.970896
# 2024-01-01 00:20:00     878.416710     59.200001     15.000000   0.970878
# ...                            ...           ...           ...        ...
# 2024-09-15 23:35:00     870.865216    100.000000     26.103367   0.945172
# 2024-09-15 23:40:00     869.007829    100.000000     26.093265   0.948517
# 2024-09-15 23:45:00     867.712970    100.000000     26.100000   0.949882
# 2024-09-15 23:50:00     867.684024    100.000000     26.078118   0.949256
# 2024-09-15 23:55:00     868.045556    100.000000     26.066269   0.946246
#
#                      DeSOx_2nd      前爐SOx濃度       鈣硫比
# datetime
# 2024-01-01 00:00:00   0.871410  2230.093232  2.223152
# 2024-01-01 00:05:00   0.877787  2220.527929  2.220789
# 2024-01-01 00:10:00   0.871768  2237.129686  2.217612
# 2024-01-01 00:15:00   0.882700  2227.895501  2.214444
# 2024-01-01 00:20:00   0.905103  2211.052236  2.211285
# ...                        ...          ...       ...
# 2024-09-15 23:35:00   0.885205  2082.274527  3.928554
# 2024-09-15 23:40:00   0.907156  2071.948976  3.927730
# 2024-09-15 23:45:00   0.910708  2088.339754  3.928170
# 2024-09-15 23:50:00   0.919579  2034.665472  3.927928
# 2024-09-15 23:55:00   0.918868  2048.422596  3.928171
#
# [74592 rows x 60 columns]

# %% [markdown]
# # 篩選資料

# %%
coal_low = df[df["MLUT4_FIQ-2BTCF"] < 20]
sox = df["MLUT4_AT-240"]
constant_sox_indices = sox[sox.shift(1) == sox][(sox.shift(2) == sox) & (sox.shift(-1) == sox)].index
constant_sox = df.loc[constant_sox_indices]
common_index = coal_low.index.union(constant_sox.index)
select_df = df.loc[~df.index.isin(common_index), :]
select_df[["MLUT4_FIQ-2BTCF","MLUT4_AT-240"]]
# Out:
#                      MLUT4_FIQ-2BTCF  MLUT4_AT-240
# datetime
# 2024-01-01 00:00:00        37.784191      8.619934
# 2024-01-01 00:05:00        37.824395      8.147002
# 2024-01-01 00:10:00        37.878584      8.247992
# 2024-01-01 00:15:00        37.932773      7.605820
# 2024-01-01 00:20:00        37.986962      6.110485
# ...                              ...           ...
# 2024-09-15 23:35:00        35.636522     13.105704
# 2024-09-15 23:40:00        35.644001      9.903673
# 2024-09-15 23:45:00        35.640006      9.345572
# 2024-09-15 23:50:00        35.642203      8.303164
# 2024-09-15 23:55:00        35.639999      8.933592
#
# [53717 rows x 2 columns]

# %% [markdown]
# # 檢查篩選結果

# %%
import plotly.express as px

# 假設 df 是你的 DataFrame
fig = px.scatter(
    select_df[["MLUT4_FIQ-2BTCF","MLUT4_AT-240"]],
    x="MLUT4_FIQ-2BTCF",
    y="MLUT4_AT-240",
    title="MLUT4_FIQ-2BTCF vs MLUT4_AT-240 散點圖",
    labels={
        "MLUT4_FIQ-2BTCF": "FIQ-2BTCF",
        "MLUT4_AT-240": "AT-240"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2076cf73-4994-4f95-a3d1-84a3090c17c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
#  'MLUT4_TE-251H',
#  'MLUT4_AT-232A',
#  'MLUT4_TE-252I',
#  'MLUT4_IT-E7925A',
#  'MLUT4_FQ-205',
#  'MLUT4_FIC-233',
#  'MLUT4_ZT-232',
#  'MLUT4_FT-V004',
#  'MLUT4_PT-231',
#  'MLUT4_FT-232',
#  'MLUT4_AT-237',
#  'MLUT4_FT-951AB']

# %%
df.columns
# Out:
# Index(['MLUT4_AIA792101A', 'MLUT4_AIA792101B', 'MLUT4_AIC-232B',
#        'MLUT4_AT-232A', 'MLUT4_AT-237', 'MLUT4_AT-240', 'MLUT4_AT-240A',
#        'MLUT4_FIC-231A', 'MLUT4_FIC-231B', 'MLUT4_FIC-231C', 'MLUT4_FIC-233',
#        'MLUT4_FIQ-2BTCF', 'MLUT4_FQ-205', 'MLUT4_FQ-239', 'MLUT4_FT-232',
#        'MLUT4_FT-792003', 'MLUT4_FT-792020', 'MLUT4_FT-951AA',
#        'MLUT4_FT-951AB', 'MLUT4_FT-956', 'MLUT4_FT-957', 'MLUT4_FT-V004',
#        'MLUT4_IT-E7925A', 'MLUT4_IT-E7925B', 'MLUT4_PDIC-233', 'MLUT4_PDT-231',
#        'MLUT4_PDT-232', 'MLUT4_PIC-233', 'MLUT4_PT-231', 'MLUT4_RQ-2BTLS',
#        'MLUT4_RT-031', 'MLUT4_RT-041', 'MLUT4_RT-051', 'MLUT4_RT-081',
#        'MLUT4_RT-091', 'MLUT4_SIV-B7921', 'MLUT4_TE-251A', 'MLUT4_TE-251B',
#        'MLUT4_TE-251C', 'MLUT4_TE-251D', 'MLUT4_TE-251E', 'MLUT4_TE-251F',
#        'MLUT4_TE-251G', 'MLUT4_TE-251H', 'MLUT4_TE-251I', 'MLUT4_TE-252A',
#        'MLUT4_TE-252B', 'MLUT4_TE-252C', 'MLUT4_TE-252D', 'MLUT4_TE-252E',
#        'MLUT4_TE-252F', 'MLUT4_TE-252G', 'MLUT4_TE-252H', 'MLUT4_TE-252I',
#        'MLUT4_ZT-231', 'MLUT4_ZT-232', 'DeSOx_1st', 'DeSOx_2nd', '前爐SOx濃度',
#        '鈣硫比'],
#       dtype='object')

# %%
y_col = 'DeSOx_2nd'

# %%
select_df = select_df[features+[y_col]]
select_df = select_df[
    (~np.isinf(select_df[y_col])) &
    (~np.isnan(select_df[y_col]))
]
select_df
# Out:
#                      MLUT4_FT-956  MLUT4_FT-957  MLUT4_FIC-231C  \
# datetime
# 2024-01-01 00:00:00   3992.840799   3917.594740       17.456094
# 2024-01-01 00:05:00   3988.473250   3917.320459       17.449118
# 2024-01-01 00:10:00   3984.113830   3913.623750       17.442142
# 2024-01-01 00:15:00   3984.936436   3929.257511       17.571883
# 2024-01-01 00:20:00   3985.762194   3914.198450       17.339679
# ...                           ...           ...             ...
# 2024-09-15 23:35:00   2630.971265   2639.985169       12.842200
# 2024-09-15 23:40:00   2637.921800   2644.140047       12.823741
# 2024-09-15 23:35:00     227.094066     26.103367           1.87   1361.905776
# 2024-09-15 23:40:00     226.873818     26.093265           1.87   1364.378553
# 2024-09-15 23:45:00     227.212922     26.100000           1.87   1368.033108
# 2024-09-15 23:50:00     227.050551     26.078118           1.87   1366.118718
# 2024-09-15 23:55:00     227.420687     26.066269           1.87   1362.451729
#
#                      MLUT4_FT-232  MLUT4_AT-237  MLUT4_FT-951AB  DeSOx_2nd
# datetime
# 2024-01-01 00:00:00    359.664266      9.623605       99.231466   0.871410
# 2024-01-01 00:05:00    359.556551      9.616252      100.033768   0.877787
# 2024-01-01 00:10:00    355.172410      9.608899       99.932670   0.871768
# 2024-01-01 00:15:00    355.875036      9.600898       99.831572   0.882700
# 2024-01-01 00:20:00    356.333792      9.581994      100.181768   0.905103
# ...                           ...           ...             ...        ...
# 2024-09-15 23:35:00    243.293496      9.360355       97.405392   0.885205
# 2024-09-15 23:40:00    241.649951      9.280099       97.528753   0.907156
# 2024-09-15 23:45:00    244.585288      9.359701       98.286113   0.910708
# 2024-09-15 23:50:00    245.330280      9.211132       99.519681   0.919579
# 2024-09-15 23:55:00    249.288039      9.231066       98.966342   0.918868
#
# [52826 rows x 26 columns]

# %% [markdown]
# 預測目標:DeSOx_1st 其餘為特徵
#
# 1. 先將數據select_df依據時間排序。
#
# 2. 自第1001筆開始，取用前1000筆數據建立rf模型，評估建模數據的"預測誤差絕對值"，計算前述數值的第80百分位數當成"門檻值"。
#
# 3. 運用2.的模型執行第1001筆的預測。
#
# 4. 比對3.的結果之"預測誤差絕對值"。若此數值超過"門檻值"，則第1002筆預測重複2.＆3.步驟；若此數值不超過"門檻值"，直接運用2.的模型執行第1002筆的預測。
#
# 5. 之後以此類推....

# %%
select_df.columns
# Out:
# Index(['MLUT4_FT-956', 'MLUT4_FT-957', 'MLUT4_FIC-231C', 'MLUT4_FIC-231B',
#        'MLUT4_PDT-232', 'MLUT4_PIC-233', 'MLUT4_FIC-231A', 'MLUT4_TE-252D',
#        'MLUT4_FQ-239', 'MLUT4_IT-E7925B', 'MLUT4_RT-091', 'MLUT4_AIA792101B',
#        'MLUT4_FT-792020', 'MLUT4_TE-251H', 'MLUT4_AT-232A', 'MLUT4_TE-252I',
#        'MLUT4_IT-E7925A', 'MLUT4_FQ-205', 'MLUT4_FIC-233', 'MLUT4_ZT-232',
#        'MLUT4_FT-V004', 'MLUT4_PT-231', 'MLUT4_FT-232', 'MLUT4_AT-237',
#        'MLUT4_FT-951AB', 'DeSOx_2nd'],
#       dtype='object')

# %%
select_df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# ======================== 使用者自定義超參數 ==========================
PERCENTILE_THRESHOLD = 95     # 門檻百分位
PREDICTION_INTERVAL = 300     # 每次預測區間 (筆數)
MAX_STEPS = 1000              # 最多預測幾次（非總筆數）
WINDOW_SIZE = 1000            # 每次用多少資料訓練
# =====================================================================

# 1. 資料排序
select_df = select_df.sort_index().reset_index(drop=True)

# 2. 設定欄位
target_col = y_col
feature_cols = [col for col in select_df.columns if col not in ['timestamp', target_col]]
start_idx = WINDOW_SIZE

# 3. 儲存預測結果
predictions = []
abs_errors = []
thresholds = []
indices = []

# 4. 初始化進度條
pbar = tqdm(total=MAX_STEPS)

# 5. 初始模型與門檻
model = None
cached_threshold = None

# 6. 開始迴圈
i = start_idx
while i + PREDICTION_INTERVAL <= len(select_df):
    if pbar.n >= MAX_STEPS:
        print(f"已達 {MAX_STEPS} 步，提前結束迴圈")
        break

    retrain_model = False

    # 如果還沒模型，或是前次預測誤差超門檻 → 重訓
    if model is None:
        retrain_model = True
    else:
        # 快速預測一整段並計算誤差
        test_df = select_df.iloc[i:i+PREDICTION_INTERVAL]
        test_X = test_df[feature_cols]
        true_y = test_df[target_col].values
        preds = model.predict(test_X)
        errors = np.abs(preds - true_y)

        # 如果任一筆超門檻 → 重訓
        if cached_threshold is not None and np.any(errors > cached_threshold):
            retrain_model = True

    if retrain_model:
        train_df = select_df.iloc[i - WINDOW_SIZE:i]
        train_X = train_df[feature_cols]
        train_y = train_df[target_col]

        model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
        model.fit(train_X, train_y)

        train_preds = model.predict(train_X)
        train_errors = np.abs(train_preds - train_y)
        cached_threshold = np.percentile(train_errors, PERCENTILE_THRESHOLD)

        # 預測下一段（剛好可以重用 test_df）
        test_df = select_df.iloc[i:i+PREDICTION_INTERVAL]
        test_X = test_df[feature_cols]
        true_y = test_df[target_col].values
        preds = model.predict(test_X)
        errors = np.abs(preds - true_y)

    # 紀錄整段結果
    idx_range = list(range(i, i + PREDICTION_INTERVAL))
    predictions.extend(preds.tolist())
    abs_errors.extend(errors.tolist())
    thresholds.extend([cached_threshold] * len(preds))
    indices.extend(idx_range)

    pbar.update(1)
    i += PREDICTION_INTERVAL

pbar.close()

# 7. 輸出結果表
result_df = select_df.loc[indices].copy()
result_df['prediction'] = predictions
result_df['abs_error'] = abs_errors
result_df['threshold'] = thresholds

result_df.head()
# Out:
#  17%|█▋        | 172/1000 [07:02<33:55,  2.46s/it]
#       MLUT4_FT-956  MLUT4_FT-957  MLUT4_FIC-231C  MLUT4_FIC-231B  \
# 1000   3982.933325   3936.791882       20.747748             0.0
# 1001   3983.544241   3929.114039       20.960797             0.0
# 1002   3985.621893   3932.630585       21.395041             0.0
# 1003   3982.279510   3933.459131       21.195365             0.0
# 1004   3979.527359   3935.727198       20.726037             0.0
#
#       MLUT4_PDT-232  MLUT4_PIC-233  MLUT4_FIC-231A  MLUT4_TE-252D  \
# 1000     108.214745    1102.994320       22.632297     894.113646
# 1001     107.243364    1103.196519       22.628941     895.076073
# 1002     107.787313    1102.844015       22.625585     895.779150
# 1003     107.991793    1102.583847       22.622228     896.204024
# 1004     107.857274    1101.892047       22.618872     896.507485
#
#       MLUT4_FQ-239  MLUT4_IT-E7925B  ...  MLUT4_ZT-232  MLUT4_FT-V004  \
# 1000    439.918414        17.033064  ...          14.9            0.0
# 1001    439.210893        16.983876  ...          14.9            0.0
# 1002    438.327778        17.100930  ...          14.9            0.0
# 1003    440.688510        17.007116  ...          14.9            0.0
# 1004    439.515343        17.061303  ...          14.9            0.0
#
#       MLUT4_PT-231  MLUT4_FT-232  MLUT4_AT-237  MLUT4_FT-951AB  DeSOx_2nd  \
# 1000   1406.945243    330.686470      6.675483       95.036593   0.912031
# 1001   1408.903645    333.591439      6.661739       95.353668   0.902823
# 1002   1405.631145    337.282611      6.647995       95.629688   0.887299
# 1003   1407.407529    340.031637      6.634251       95.528780   0.883433
# 1004   1405.892220    331.664549      6.620507       95.852248   0.883650
#
#       prediction  abs_error  threshold
# 1000    0.907622   0.004409   0.022871
# 1001    0.905920   0.003096   0.022871
# 1002    0.906567   0.019268   0.022871
# 1003    0.907920   0.024487   0.022871
# 1004    0.904438   0.020788   0.022871
#
# [5 rows x 29 columns]

# %%
result_df[[y_col,'prediction','abs_error','threshold']]
# Out:
#        DeSOx_2nd  prediction  abs_error  threshold
# 1000    0.912031    0.907622   0.004409   0.022871
# 1001    0.902823    0.905920   0.003096   0.022871
# 1002    0.887299    0.906567   0.019268   0.022871
# 1003    0.883433    0.907920   0.024487   0.022871
# 1004    0.883650    0.904438   0.020788   0.022871
# ...          ...         ...        ...        ...
# 52595   0.905129    0.875714   0.029414   0.010847
# 52596   0.918045    0.876285   0.041760   0.010847
# 52597   0.906779    0.873891   0.032888   0.010847
# 52598   0.911114    0.871978   0.039136   0.010847
# 52599   0.907466    0.873497   0.033968   0.010847
#
# [51600 rows x 4 columns]

# %%
result_df.loc['AVG',:] = result_df[[y_col,'prediction','abs_error','threshold']].mean(axis=0)
result_df[[y_col,'prediction','abs_error','threshold']]
# Out:
#        DeSOx_2nd  prediction  abs_error  threshold
# 1000    0.912031    0.907622   0.004409   0.022871
# 1001    0.902823    0.905920   0.003096   0.022871
# 1002    0.887299    0.906567   0.019268   0.022871
# 1003    0.883433    0.907920   0.024487   0.022871
# 1004    0.883650    0.904438   0.020788   0.022871
# ...          ...         ...        ...        ...
# 52596   0.918045    0.876285   0.041760   0.010847
# 52597   0.906779    0.873891   0.032888   0.010847
# 52598   0.911114    0.871978   0.039136   0.010847
# 52599   0.907466    0.873497   0.033968   0.010847
# AVG     0.740797    0.338905   0.618532   0.048936
#
# [51601 rows x 4 columns]

# %%
import plotly.express as px

fig = px.line(result_df, y='abs_error', title='Absolute Error over Samples')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c31ff9e9-2aed-424e-b88c-90e027a22c0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c31ff9e9-2aed-424e-b88c-90e027a22c0d")) {                    Plotly.newPlot(                        "c31ff9e9-2aed-424e-b88c-90e027a22c0d",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eabs_error=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1086,1087,1088,1089,1090,1091,1092,1093,1094,1095,1096,1097,1098,1099,1100,1101,1102,1103,1104,1105,1106,1107,1108,1109,1110,1111,1112,1113,1114,1115,1116,1117,1118,1119,1120,1121,1122,1123,1124,1125,1126,1127,1128,1129,1130,1131,1132,1133,1134,1135,1136,1137,1138,1139,1140,1141,1142,1143,1144,1145,1146,1147,1148,1149,1150,1151,1152,1153,1154,1155,1156,1157,1158,1159,1160,1161,1162,1163,1164,1165,1166,1167,1168,1169,1170,1171,1172,1173,1174,1175,1176,1177,1178,1179,1180,1181,1182,1183,1184,1185,1186,1187,1188,1189,1190,1191,1192,1193,1194,1195,1196,1197,1198,1199,1200,1201,1202,1203,1204,1205,1206,1207,1208,1209,1210,1211,1212,1213,1214,1215,1216,1217,1218,1219,1220,1221,1222,1223,1224,1225,1226,1227,1228,1229,1230,1231,1232,1233,1234,1235,1236,1237,1238,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1252,1253,1254,1255,1256,1257,1258,1259,1260,1261,1262,1263,1264,1265,1266,1267,1268,1269,1270,1271,1272,1273,1274,1275,1276,1277,1278,1279,1280,1281,1282,1283,1284,1285,1286,1287,1288,1289,1290,1291,1292,1293,1294,1295,1296,1297,1298,1299,1300,1301,1302,1303,1304,1305,1306,1307,1308,1309,1310,1311,1312,1313,1314,1315,1316,1317,1318,1319,1320,1321,1322,1323,1324,1325,1326,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1361,1362,1363,1364,1365,1366,1367,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1378,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1406,1407,1408,1409,1410,1411,1412,1413,1414,1415,1416,1417,1418,1419,1420,1421,1422,1423,1424,1425,1426,1427,1428,1429,1430,1431,1432,1433,1434,1435,1436,1437,1438,1439,1440,1441,1442,1443,1444,1445,1446,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1473,1474,1475,1476,1477,1478,1479,1480,1481,1482,1483,1484,1485,1486,1487,1488,1489,1490,1491,1492,1493,1494,1495,1496,1497,1498,1499,1500,1501,1502,1503,1504,1505,1506,1507,1508,1509,1510,1511,1512,1513,1514,1515,1516,1517,1518,1519,1520,1521,1522,1523,1524,1525,1526,1527,1528,1529,1530,1531,1532,1533,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1554,1555,1556,1557,1558,1559,1560,1561,1562,1563,1564,1565,1566,1567,1568,1569,1570,1571,1572,1573,1574,1575,1576,1577,1578,1579,1580,1581,1582,1583,1584,1585,1586,1587,1588,1589,1590,1591,1592,1593,1594,1595,1596,1597,1598,1599,1600,1601,1602,1603,1604,1605,1606,1607,1608,1609,1610,1611,1612,1613,1614,1615,1616,1617,1618,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1 ...
